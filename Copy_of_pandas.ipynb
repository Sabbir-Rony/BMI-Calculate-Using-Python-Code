# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabbir-Rony/BMI-Calculate-Using-Python-Code/blob/main/Copy_of_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
diabetes_df = pd.read('/content/diabetes.csv')
pd.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1207954627.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 diabetes_df = pd.read('/content/diabetes.csv')
#       3 pd.head()
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
# !pip install pandas

# %%
import pandas as pd
diabetes_df = pd.read_csv('/content/diabetes.csv')
diabetes_df.head()
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %%
boston_df.to_csv('boston.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3148085126.py in <cell line: 0>()
# ----> 1 boston_df.to_csv('boston.csv')
#
# NameError: name 'boston_df' is not defined

# %%
boston_df = pd.read_csv('boston.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2580476457.py in <cell line: 0>()
# ----> 1 boston_df = pd.read_csv('boston.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %% [markdown]
# Loading the data from a excel file to a pandas dataframe

# %%
import pandas as pd
import numpy as np
random_df = pd.DataFrame(np.random.rand(20,10))
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.734701  0.362481  0.660492  0.126612  0.171870  0.594323  0.257446
# 1  0.097632  0.052342  0.594328  0.496046  0.217867  0.394272  0.270891
# 2  0.696716  0.299459  0.679710  0.450838  0.115429  0.764283  0.610701
# 3  0.759028  0.775219  0.853210  0.974633  0.143174  0.090784  0.915954
# 4  0.731434  0.802667  0.712384  0.543312  0.894383  0.785481  0.261384
#
#           7         8         9
# 0  0.514302  0.862320  0.034013
# 1  0.847740  0.115849  0.238987
# 2  0.413700  0.650232  0.671773
# 3  0.509392  0.167972  0.113253
# 4  0.642790  0.828129  0.345597

# %%
random_df.shape
# Out:
# (20, 10)

# %%
#finding the number of coloum and row
diabetes_df.shape
# Out:
# (768, 9)

# %%
#print last 5 rows the dataframe
diabetes_df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#information about the dataframe
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
 #finding the number of missing vzalues
 diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#coujnting the values on the labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_df.value_counts('Age')
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 32    16
# 38    16
# 36    16
# 45    15
# 34    14
# 46    13
# 43    13
# 40    13
# 39    12
# 35    10
# 44     8
# 51     8
# 50     8
# 52     8
# 58     7
# 54     6
# 47     6
# 49     5
# 53     5
# 57     5
# 48     5
# 60     5
# 55     4
# 63     4
# 62     4
# 66     4
# 56     3
# 65     3
# 59     3
# 67     3
# 61     2
# 69     2
# 64     1
# 68     1
# 70     1
# 72     1
# 81     1
# Name: count, dtype: int64

# %%
#group of the values based on the mean
diabetes_df.groupby('Age').mean()
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Age
# 21      1.079365  108.317460      65.936508      19.349206   73.634921
# 22      1.555556  108.208333      63.722222      20.486111   74.486111
# 23      1.578947  111.578947      64.315789      22.368421  118.026316
# 24      1.891304  117.891304      64.956522      25.934783   88.021739
# 25      1.770833  110.083333      59.666667      23.958333   82.895833
# 26      1.969697  118.212121      64.181818      23.666667   90.878788
# 27      2.562500  115.281250      73.500000      18.375000   63.125000
# 28      3.028571  119.914286      68.314286      23.628571   94.600000
# 29      3.310345  127.379310      68.241379      21.000000   88.793103
# 30      3.619048  122.285714      64.857143      18.904762   82.666667
# 31      3.875000  126.958333      64.375000      20.000000  111.166667
# 32      4.437500  116.312500      70.062500      18.187500   35.812500
# ...

# %%
#count o the number of values
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
diabetes_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
#standered division -coloums wise
diabetes_df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
#minimum values
diabetes_df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
#max values
diabetes_df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
# all the statistical measures about the dataframe
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Manupulating dataframe

# %%
#adsding a column to a dataframe
diabetes_df['Cost'] = 0 # Placeholder for a new column
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Cost
# 0                     0.627   50        1     0
# 1                     0.351   31        0     0
# 2                     0.672   32        1     0
# 3                     0.167   21        0     0
# 4                     2.288   33        1     0

# %%
import pandas as pd
diabetes_df = pd.read_csv('/content/diabetes.csv')
diabetes_df.head()
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Replace 0 with 'False' and 1 with 'True' in the 'Outcome' column
diabetes_df['Outcome'] = diabetes_df['Outcome'].replace({0: False, 1: True})

# Display the updated head of the dataframe
diabetes_df.head()
# Out:
# /tmp/ipython-input-2028906953.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   diabetes_df['Outcome'] = diabetes_df['Outcome'].replace({0: False, 1: True})
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50     True
# 1                     0.351   31    False
# ...

# %%
#removing a row
diabetes_df.drop(index=1, axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50     True
# ...

# %%
#removing thew coloum
diabetes_df.drop(columns='Insulin', axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  \
# 0              6      148             72             35  33.6
# 1              1       85             66             29  26.6
# 2              8      183             64              0  23.3
# 3              1       89             66             23  28.1
# 4              0      137             40             35  43.1
# ..           ...      ...            ...            ...   ...
# 763           10      101             76             48  32.9
# 764            2      122             70             27  36.8
# 765            5      121             72             23  26.2
# 766            1      126             60              0  30.1
# 767            1       93             70             31  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50     True
# 1                       0.351   31    False
# 2                       0.672   32     True
# ...

# %%
#find out the rows values index
diabetes_df.iloc[3]
# Out:
# Pregnancies                     1
# Glucose                        89
# BloodPressure                  66
# SkinThickness                  23
# Insulin                        94
# BMI                          28.1
# DiabetesPedigreeFunction    0.167
# Age                            21
# Outcome                     False
# Name: 3, dtype: object

# %%
#find out the exact index
print(diabetes_df.iloc[:,3])
#find out the exact index
print(diabetes_df.iloc[:,-1])
print(diabetes_df.iloc[:,5])
# Out:
# 0      35
# 1      29
# 2       0
# 3      23
# 4      35
#        ..
# 763    48
# 764    27
# 765    23
# 766     0
# 767    31
# Name: SkinThickness, Length: 768, dtype: int64
# 0      Positive
# 1      Negative
# 2      Positive
# 3      Negative
# 4      Positive
#          ...
# 763    Negative
# 764    Negative
# 765    Negative
# 766    Positive
# 767    Negative
# Name: Outcome, Length: 768, dtype: object
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
import pandas as pd

# Load the dataset
diabetes_df = pd.read_csv('/content/diabetes.csv')

# Replace 0 with 'Negative' and 1 with 'Positive' in the 'Outcome' column
diabetes_df['Outcome'] = diabetes_df['Outcome'].replace({0: 'Negative', 1: 'Positive'})

# Display the updated head of the dataframe
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age   Outcome
# 0                     0.627   50  Positive
# 1                     0.351   31  Negative
# 2                     0.672   32  Positive
# 3                     0.167   21  Negative
# 4                     2.288   33  Positive

# %% [markdown]
#  correlation
#  1.positive
#  2.negative

# %%
import pandas as pd

# Load the dataset
diabetes_df = pd.read_csv('/content/diabetes.csv')
diabetes_df.head()
diabetes_df.corr()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3702405940.py in <cell line: 0>()
#       2
#       3 # Load the dataset
# ----> 4 diabetes_df = pd.read_csv('/content/diabetes.csv')
#       5 diabetes_df.head()
#       6 diabetes_df.corr()
#
# ...

# %%
import pandas as pd
import os

# Define the file path
file_path = '/content/diabetes.csv'

# Check if the file exists before attempting to read
if os.path.exists(file_path):
    # Load the dataset
    diabetes_df = pd.read_csv(file_path)

    # Display the head of the dataframe
    print("DataFrame head:")
    display(diabetes_df.head())

    # Calculate and display the correlation matrix
    print("\nCorrelation Matrix:")
    display(diabetes_df.corr())
else:
    print(f"Error: The file '{file_path}' was not found.")
    print("Please make sure the file is uploaded to your Colab environment and the path is correct.")
# Out:
# Error: The file '/content/diabetes.csv' was not found.
# Please make sure the file is uploaded to your Colab environment and the path is correct.

# %%
import pandas as pd
diabetes_df = pd.read_csv('/content/diabetes.csv')
diabetes_df.head()
diabetes_df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...
